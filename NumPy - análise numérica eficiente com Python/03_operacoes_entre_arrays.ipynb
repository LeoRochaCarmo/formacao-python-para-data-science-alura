# %% [markdown]
# #### Diferença entre arrays

# %%
import pandas as pd
import numpy as np

SHEET_PATH = 'data/apples_ts.csv'

df = pd.read_csv(SHEET_PATH)
columns_to_use = np.arange(1, len(df.columns), 1)

data = np.loadtxt(SHEET_PATH, delimiter=',', usecols=columns_to_use)
transposed_data = data.transpose()

dates = np.arange(1, len(df.columns), 1)

num_of_col = len(pd.DataFrame(transposed_data).columns)
prices = transposed_data[:,1:num_of_col]

moscow, kaliningrad, petersburg, krasnodar, ekaterinburg = [city_prices for city_prices in prices.transpose()]

# %% [markdown]
# #### Ajustar reta para entender a taxa de crescimento do preço

# %% [markdown]
# ##### Calculando a e b por tentativa e erro (y = ax + b)

# %%
x = dates
y = 0.5 * x + 80

# %%
np.linalg.norm(moscow-y) # retorna a norma do vetor
# Out:
# 107.16853129533874

# %%
import matplotlib.pyplot as plt

plt.plot(dates, moscow)
plt.plot(dates, y, linestyle='dashed')

# %% [markdown]
# ##### Calculando coeficiente angular e linear da reta

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
y = moscow
x = dates
n = np.size(moscow)

a = (n*np.sum(x*y) - np.sum(x)*np.sum(y)) / (n*np.sum(x**2) - np.sum(x)**2)
a
# Out:
# 0.43520212145512926
